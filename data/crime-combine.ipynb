# %%
import pandas as pd
import numpy as np

# %%
crime_2016 = pd.read_csv("Crime_Incidents_in_2016.csv")
crime_2017 = pd.read_csv("Crime_Incidents_in_2017.csv")
crime_2018 = pd.read_csv("Crime_Incidents_in_2018.csv")
crime_2019 = pd.read_csv("Crime_Incidents_in_2019.csv")

# %%
crime_2016.head()
# Out:
#            X          Y       CCN                REPORT_DAT     SHIFT  METHOD  \
# 0 -76.997328  38.885141   1020310  2016-02-09T13:46:39.000Z       DAY  OTHERS
# 1 -76.969243  38.851752   6021842  2016-02-12T13:31:08.000Z       DAY  OTHERS
# 2 -77.065954  38.948361   6080644  2016-05-20T19:04:31.000Z   EVENING  OTHERS
# 3 -76.952700  38.919922  10151260  2016-09-07T14:13:47.000Z       DAY  OTHERS
# 4 -76.987356  38.898536  10205222  2016-12-04T03:11:26.000Z  MIDNIGHT  OTHERS
#
#         OFFENSE                                       BLOCK  XBLOCK  YBLOCK  \
# 0   THEFT/OTHER   600 - 669 BLOCK OF PENNSYLVANIA AVENUE SE  400232  135255
# 1   THEFT/OTHER       2600 - 2799 BLOCK OF JASPER STREET SE  402670  131549
# 2   THEFT/OTHER  4500 - 4529 BLOCK OF CONNECTICUT AVENUE NW  394283  142275
# 3  THEFT F/AUTO       2400 - 2499 BLOCK OF MARKET STREET NE  404102  139117
# 4  THEFT F/AUTO     1300 - 1353 BLOCK OF MARYLAND AVENUE NE  401097  136742
#
# ...

# %%
crime_total = [crime_2016, crime_2017, crime_2018, crime_2019]
merged_crime = pd.concat(crime_total, sort=False)

# %%
merged_crime.sort_values(by=['START_DATE'])
# Out:
#                X          Y       CCN                REPORT_DAT     SHIFT  \
# 6091  -76.939276  38.880982  16027878  2016-02-23T23:14:15.000Z  MIDNIGHT
# 4587  -77.072294  38.921513  16038136  2016-03-12T16:02:12.000Z   EVENING
# 9994  -76.986569  38.915147  16061294  2016-04-19T21:44:46.000Z   EVENING
# 12408 -76.990911  38.862314  16062236  2016-04-21T13:21:51.000Z       DAY
# 12421 -76.998620  38.826055  16064838  2016-04-25T16:36:42.000Z   EVENING
# 14312 -76.972782  38.845663  16073374  2016-05-09T11:44:47.000Z       DAY
# 15192 -77.041868  38.911330  17093717  2017-06-03T00:24:27.000Z  MIDNIGHT
# 33634 -77.010264  38.911860  85017166  2018-02-27T00:00:00.000Z  MIDNIGHT
# 33633 -77.010264  38.911860  85017166  2018-02-27T00:00:00.000Z  MIDNIGHT
# 33618 -76.999311  38.845838  91603502  2018-12-10T00:00:00.000Z  MIDNIGHT
# 20195 -76.998459  38.842495  16114928  2016-07-12T06:00:17.000Z  MIDNIGHT
# 394   -76.993828  38.841432  16002801  2016-01-06T01:44:30.000Z  MIDNIGHT
# ...

# %%
new = merged_crime["START_DATE"].str.split("-", expand = True)
new.head()
# Out:
#       0   1                 2
# 0  2016  01  19T17:00:03.000Z
# 1  2016  02  06T18:30:37.000Z
# 2  2016  05  11T11:00:13.000Z
# 3  2016  09  07T14:00:24.000Z
# 4  2016  12  03T20:00:00.000Z

# %%
# new[0].value_counts()
merged_crime["report_year"] = new[0]

# %%
merged_crime.head()
# Out:
#            X          Y       CCN                REPORT_DAT     SHIFT  METHOD  \
# 0 -76.997328  38.885141   1020310  2016-02-09T13:46:39.000Z       DAY  OTHERS
# 1 -76.969243  38.851752   6021842  2016-02-12T13:31:08.000Z       DAY  OTHERS
# 2 -77.065954  38.948361   6080644  2016-05-20T19:04:31.000Z   EVENING  OTHERS
# 3 -76.952700  38.919922  10151260  2016-09-07T14:13:47.000Z       DAY  OTHERS
# 4 -76.987356  38.898536  10205222  2016-12-04T03:11:26.000Z  MIDNIGHT  OTHERS
#
#         OFFENSE                                       BLOCK    XBLOCK  \
# 0   THEFT/OTHER   600 - 669 BLOCK OF PENNSYLVANIA AVENUE SE  400232.0
# 1   THEFT/OTHER       2600 - 2799 BLOCK OF JASPER STREET SE  402670.0
# 2   THEFT/OTHER  4500 - 4529 BLOCK OF CONNECTICUT AVENUE NW  394283.0
# 3  THEFT F/AUTO       2400 - 2499 BLOCK OF MARKET STREET NE  404102.0
# 4  THEFT F/AUTO     1300 - 1353 BLOCK OF MARYLAND AVENUE NE  401097.0
#
#      YBLOCK  ...  CENSUS_TRACT VOTING_PRECINCT   LATITUDE  LONGITUDE  \
# ...

# %%
merged_crime['report_year']= merged_crime['report_year'].astype(int)

# %%
merged_crime = merged_crime[merged_crime.report_year >= 2016]

# %%
merged_crime['report_year'].value_counts()
# Out:
# 2016    37146
# 2018    33641
# 2017    33002
# 2019    19473
# Name: report_year, dtype: int64

# %%
# merged_crime['START_DATE']= merged_crime['START_DATE'].astype(str)

# %%
merged_crime['START_DATE']= merged_crime['START_DATE'].map(lambda x: str(x)[:-14])

# %%
merged_crime.head()
# Out:
#            X          Y       CCN                REPORT_DAT     SHIFT  METHOD  \
# 0 -76.997328  38.885141   1020310  2016-02-09T13:46:39.000Z       DAY  OTHERS
# 1 -76.969243  38.851752   6021842  2016-02-12T13:31:08.000Z       DAY  OTHERS
# 2 -77.065954  38.948361   6080644  2016-05-20T19:04:31.000Z   EVENING  OTHERS
# 3 -76.952700  38.919922  10151260  2016-09-07T14:13:47.000Z       DAY  OTHERS
# 4 -76.987356  38.898536  10205222  2016-12-04T03:11:26.000Z  MIDNIGHT  OTHERS
#
#         OFFENSE                                       BLOCK    XBLOCK  \
# 0   THEFT/OTHER   600 - 669 BLOCK OF PENNSYLVANIA AVENUE SE  400232.0
# 1   THEFT/OTHER       2600 - 2799 BLOCK OF JASPER STREET SE  402670.0
# 2   THEFT/OTHER  4500 - 4529 BLOCK OF CONNECTICUT AVENUE NW  394283.0
# 3  THEFT F/AUTO       2400 - 2499 BLOCK OF MARKET STREET NE  404102.0
# 4  THEFT F/AUTO     1300 - 1353 BLOCK OF MARYLAND AVENUE NE  401097.0
#
#      YBLOCK  ...  CENSUS_TRACT VOTING_PRECINCT   LATITUDE  LONGITUDE  \
# ...

# %%
crime_count = merged_crime.groupby('START_DATE')['CCN'].count()
crime_count
# Out:
# START_DATE
# 2016-01-01    103
# 2016-01-02     93
# 2016-01-03    100
# 2016-01-04     77
# 2016-01-05     92
# 2016-01-06     88
# 2016-01-07     78
# 2016-01-08    120
# 2016-01-09     89
# 2016-01-10     84
# 2016-01-11    107
# 2016-01-12     94
# 2016-01-13     92
# 2016-01-14     92
# 2016-01-15    119
# 2016-01-16    109
# 2016-01-17     81
# 2016-01-18     68
# 2016-01-19     89
# 2016-01-20     71
# 2016-01-21     95
# 2016-01-22     63
# 2016-01-23     28
# 2016-01-24     38
# 2016-01-25     36
# 2016-01-26     62
# 2016-01-27     73
# 2016-01-28     78
# 2016-01-29     91
# 2016-01-30     94
#              ...
# 2019-07-14     99
# 2019-07-15    110
# 2019-07-16     84
# 2019-07-17     97
# 2019-07-18     73
# 2019-07-19     89
# 2019-07-20     95
# 2019-07-21     88
# 2019-07-22    114
# 2019-07-23     96
# 2019-07-24    104
# 2019-07-25    106
# 2019-07-26    122
# 2019-07-27    118
# 2019-07-28    109
# 2019-07-29    106
# 2019-07-30    123
# 2019-07-31     90
# ...

# %%
merged_crime.to_csv("combined_crime.csv", index=False)

# %%
crime_date_count = merged_crime.groupby('START_DATE')['CCN'].nunique()
crime_date_count_df = pd.DataFrame(crime_date_count)
crime_date_count_df.head()
# Out:
#             CCN
# START_DATE
# 2016-01-01  103
# 2016-01-02   93
# 2016-01-03  100
# 2016-01-04   77
# 2016-01-05   92

# %%
crime_date_count_df.rename(columns={'CCN': 'crime-count'})
# Out:
#             crime-count
# START_DATE
# 2016-01-01          103
# 2016-01-02           93
# 2016-01-03          100
# 2016-01-04           77
# 2016-01-05           92
# 2016-01-06           88
# 2016-01-07           78
# 2016-01-08          120
# 2016-01-09           89
# 2016-01-10           84
# 2016-01-11          107
# 2016-01-12           94
# 2016-01-13           92
# 2016-01-14           92
# 2016-01-15          119
# 2016-01-16          109
# 2016-01-17           81
# 2016-01-18           68
# 2016-01-19           89
# 2016-01-20           71
# 2016-01-21           95
# 2016-01-22           63
# 2016-01-23           28
# 2016-01-24           38
# 2016-01-25           36
# 2016-01-26           62
# 2016-01-27           73
# 2016-01-28           78
# 2016-01-29           91
# 2016-01-30           94
# ...                 ...
# 2019-07-14           99
# 2019-07-15          110
# 2019-07-16           84
# 2019-07-17           97
# 2019-07-18           73
# ...

# %%
crime_date_count_df.reset_index()
# Out:
#       START_DATE  CCN
# 0     2016-01-01  103
# 1     2016-01-02   93
# 2     2016-01-03  100
# 3     2016-01-04   77
# 4     2016-01-05   92
# 5     2016-01-06   88
# 6     2016-01-07   78
# 7     2016-01-08  120
# 8     2016-01-09   89
# 9     2016-01-10   84
# 10    2016-01-11  107
# 11    2016-01-12   94
# 12    2016-01-13   92
# 13    2016-01-14   92
# 14    2016-01-15  119
# 15    2016-01-16  109
# 16    2016-01-17   81
# 17    2016-01-18   68
# 18    2016-01-19   89
# 19    2016-01-20   71
# 20    2016-01-21   95
# 21    2016-01-22   63
# 22    2016-01-23   28
# 23    2016-01-24   38
# 24    2016-01-25   36
# 25    2016-01-26   62
# 26    2016-01-27   73
# 27    2016-01-28   78
# 28    2016-01-29   91
# 29    2016-01-30   94
# ...          ...  ...
# 1290  2019-07-14   99
# 1291  2019-07-15  110
# 1292  2019-07-16   84
# 1293  2019-07-17   97
# 1294  2019-07-18   73
# 1295  2019-07-19   88
# 1296  2019-07-20   95
# 1297  2019-07-21   88
# 1298  2019-07-22  114
# ...

# %%
crime_date_count_df.to_csv("combined_crime_counts.csv")

# %%
crime_df = crime_date_count_df
lunar_df = pd.read_csv("lunar_clean.csv")
weather_df = pd.read_csv("dc_weather_2016_2019.csv")

# %%
weather_df.head()
# Out:
#                 STATION                          NAME  DAPR  MDPR  PRCP  SNOW  \
# DATE
# 2016-01-01  USC00186350  NATIONAL ARBORETUM DC, MD US   NaN   NaN   0.0   NaN
# 2016-01-02  USC00186350  NATIONAL ARBORETUM DC, MD US   NaN   NaN   0.0   0.0
# 2016-01-03  USC00186350  NATIONAL ARBORETUM DC, MD US   NaN   NaN   0.0   NaN
# 2016-01-04  USC00186350  NATIONAL ARBORETUM DC, MD US   NaN   NaN   0.0   NaN
# 2016-01-05  USC00186350  NATIONAL ARBORETUM DC, MD US   NaN   NaN   0.0   NaN
#
#             SNWD  TMAX  TMIN  TOBS  WESD  WT01  WT03  WT04  WT06  WT11
# DATE
# 2016-01-01   NaN  56.0  41.0  42.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2016-01-02   0.0  46.0  31.0  34.0   0.0   NaN   NaN   NaN   NaN   NaN
# 2016-01-03   NaN  48.0  29.0  35.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2016-01-04   NaN  53.0  29.0  34.0   NaN   NaN   NaN   NaN   NaN   NaN
# 2016-01-05   NaN  38.0  15.0  17.0   NaN   NaN   NaN   NaN   NaN   NaN

# %%
# lunar_df.set_index('DateStr', inplace=True)
lunar_df.head()
# Out:
#             Year  Month  Date  Day  Illum
# DateStr
# 2016-01-01  2016      1     1    6   0.60
# 2016-01-02  2016      1     2    7   0.50
# 2016-01-03  2016      1     3    1   0.41
# 2016-01-04  2016      1     4    2   0.32
# 2016-01-05  2016      1     5    3   0.23

# %%
crime_df.head()
# Out:
#             CCN
# START_DATE
# 2016-01-01  103
# 2016-01-02   93
# 2016-01-03  100
# 2016-01-04   77
# 2016-01-05   92

# %%
crime_df.reset_index(inplace=True)

# %%
crime_df.rename(columns={"START_DATE":"DATE"}, inplace=True)

# %%
crime_df.head()
# Out:
#          DATE  CCN
# 0  2016-01-01  103
# 1  2016-01-02   93
# 2  2016-01-03  100
# 3  2016-01-04   77
# 4  2016-01-05   92

# %%
crime_df.set_index('DATE', inplace=True)

# %%
crime_df.head()
# Out:
#             CCN
# DATE
# 2016-01-01  103
# 2016-01-02   93
# 2016-01-03  100
# 2016-01-04   77
# 2016-01-05   92

# %%
lunar_df.reset_index(inplace=True)

# %%
lunar_df.rename(columns={"DateStr":"DATE"}, inplace=True)

# %%
lunar_df.set_index('DATE', inplace=True)
lunar_df.head()
# Out:
#             Year  Month  Date  Day  Illum
# DATE
# 2016-01-01  2016      1     1    6   0.60
# 2016-01-02  2016      1     2    7   0.50
# 2016-01-03  2016      1     3    1   0.41
# 2016-01-04  2016      1     4    2   0.32
# 2016-01-05  2016      1     5    3   0.23

# %%
weather_crime_df = pd.merge(crime_df, weather_df, on='DATE', how="left")

# %%
weather_crime_lunar_df = pd.merge(weather_crime_df, lunar_df, on='DATE', how="left")

# %%
weather_crime_lunar_df.head()
# Out:
#             CCN      STATION                          NAME  DAPR  MDPR  PRCP  \
# DATE
# 2016-01-01  103  USC00186350  NATIONAL ARBORETUM DC, MD US   NaN   NaN   0.0
# 2016-01-02   93  USC00186350  NATIONAL ARBORETUM DC, MD US   NaN   NaN   0.0
# 2016-01-03  100  USC00186350  NATIONAL ARBORETUM DC, MD US   NaN   NaN   0.0
# 2016-01-04   77  USC00186350  NATIONAL ARBORETUM DC, MD US   NaN   NaN   0.0
# 2016-01-05   92  USC00186350  NATIONAL ARBORETUM DC, MD US   NaN   NaN   0.0
#
#             SNOW  SNWD  TMAX  TMIN  ...  WT01  WT03  WT04  WT06  WT11  Year  \
# DATE                                ...
# 2016-01-01   NaN   NaN  56.0  41.0  ...   NaN   NaN   NaN   NaN   NaN  2016
# 2016-01-02   0.0   0.0  46.0  31.0  ...   NaN   NaN   NaN   NaN   NaN  2016
# 2016-01-03   NaN   NaN  48.0  29.0  ...   NaN   NaN   NaN   NaN   NaN  2016
# 2016-01-04   NaN   NaN  53.0  29.0  ...   NaN   NaN   NaN   NaN   NaN  2016
# 2016-01-05   NaN   NaN  38.0  15.0  ...   NaN   NaN   NaN   NaN   NaN  2016
# ...

# %%
weather_crime_lunar_df.reset_index(inplace=True)

# %%
weather_crime_lunar_df.head()
# Out:
#          DATE  CCN      STATION                          NAME  DAPR  MDPR  \
# 0  2016-01-01  103  USC00186350  NATIONAL ARBORETUM DC, MD US   NaN   NaN
# 1  2016-01-02   93  USC00186350  NATIONAL ARBORETUM DC, MD US   NaN   NaN
# 2  2016-01-03  100  USC00186350  NATIONAL ARBORETUM DC, MD US   NaN   NaN
# 3  2016-01-04   77  USC00186350  NATIONAL ARBORETUM DC, MD US   NaN   NaN
# 4  2016-01-05   92  USC00186350  NATIONAL ARBORETUM DC, MD US   NaN   NaN
#
#    PRCP  SNOW  SNWD  TMAX  ...  WT01  WT03  WT04  WT06  WT11  Year  Month  \
# 0   0.0   NaN   NaN  56.0  ...   NaN   NaN   NaN   NaN   NaN  2016      1
# 1   0.0   0.0   0.0  46.0  ...   NaN   NaN   NaN   NaN   NaN  2016      1
# 2   0.0   NaN   NaN  48.0  ...   NaN   NaN   NaN   NaN   NaN  2016      1
# 3   0.0   NaN   NaN  53.0  ...   NaN   NaN   NaN   NaN   NaN  2016      1
# 4   0.0   NaN   NaN  38.0  ...   NaN   NaN   NaN   NaN   NaN  2016      1
#
#    Date  Day  Illum
# 0     1    6   0.60
# 1     2    7   0.50
# ...

# %%
weather_crime_lunar_df.to_csv("combined_weather_crime_lunar_df.csv")
